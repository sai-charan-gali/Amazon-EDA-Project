# %%
import pandas as pd
df=pd.read_csv("/content/amazon.csv")
print(df.head())
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
#performing attributes
df.shape
# Out:
# (1465, 16)

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
df.size
# Out:
# 23440

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1465, step=1)

# %%
df.T
# Out:
#                                                                   0     \
# product_id                                                  B07JW9H4J1
# product_name         Wayona Nylon Braided USB to Lightning Fast Cha...
# category             Computers&Accessories|Accessories&Peripherals|...
# discounted_price                                                  ₹399
# actual_price                                                    ₹1,099
# discount_percentage                                                64%
# rating                                                             4.2
# rating_count                                                    24,269
# about_product        High Compatibility : Compatible With iPhone 12...
# user_id              AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# user_name            Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# review_id            R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# ...

# %%
df.dtypes
# Out:
# product_id             object
# product_name           object
# category               object
# discounted_price       object
# actual_price           object
# discount_percentage    object
# rating                 object
# rating_count           object
# about_product          object
# user_id                object
# user_name              object
# review_id              object
# review_title           object
# review_content         object
# img_link               object
# product_link           object
# dtype: object

# %%
df.values
# Out:
# array([['B07JW9H4J1',
#         'Wayona Nylon Braided USB to Lightning Fast Charging and Data Sync Cable Compatible for iPhone 13, 12,11, X, 8, 7, 6, 5, iPad Air, Pro, Mini (3 FT Pack of 1, Grey)',
#         'Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables',
#         ...,
#         'Looks durable Charging is fine tooNo complains,Charging is really fast, good product.,Till now satisfied with the quality.,This is a good product . The charging speed is slower than the original iPhone cable,Good quality, would recommend,https://m.media-amazon.com/images/W/WEBP_402378-T1/images/I/81---F1ZgHL._SY88.jpg,Product had worked well till date and was having no issue.Cable is also sturdy enough...Have asked for replacement and company is doing the same...,Value for money',
#         'https://m.media-amazon.com/images/W/WEBP_402378-T1/images/I/51UsScvHQNL._SX300_SY300_QL70_FMwebp_.jpg',
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1465, step=1)

# %%
#performing method operations

df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
df.tail()
# Out:
#       product_id                                       product_name  \
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 1460  Home&Kitchen|Kitchen&HomeAppliances|WaterPurif...             ₹379
# 1461  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...           ₹2,280
# 1462  Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...           ₹2,219
# 1463  Home&Kitchen|Heating,Cooling&AirQuality|Fans|E...           ₹1,399
# 1464  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...           ₹2,863
#
#      actual_price discount_percentage rating rating_count  \
# ...

# %%
df.count()
# Out:
# product_id             1465
# product_name           1465
# category               1465
# discounted_price       1465
# actual_price           1465
# discount_percentage    1465
# rating                 1465
# rating_count           1463
# about_product          1465
# user_id                1465
# user_name              1465
# review_id              1465
# review_title           1465
# review_content         1465
# img_link               1465
# product_link           1465
# dtype: int64

# %%
df.describe()
# Out:
#         product_id                                       product_name  \
# count         1465                                               1465
# unique        1351                                               1337
# top     B083342NKJ  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# freq             3                                                  5
#
#                                                  category discounted_price  \
# count                                                1465             1465
# unique                                                211              550
# top     Computers&Accessories|Accessories&Peripherals|...             ₹199
# freq                                                  233               53
#
#        actual_price discount_percentage rating rating_count  \
# count          1465                1465   1465         1463
# unique          449                  92     28         1143
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
df.nunique()
# Out:
# product_id             1351
# product_name           1337
# category                211
# discounted_price        550
# actual_price            449
# discount_percentage      92
# rating                   28
# rating_count           1143
# about_product          1293
# user_id                1194
# user_name              1194
# review_id              1194
# review_title           1194
# review_content         1212
# img_link               1412
# product_link           1465
# dtype: int64

# %%
df.isna().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
df.rename(columns={"product_id":"PRODUCT_ID"},inplace=True)

# %%
print(df)
# Out:
#       PRODUCT_ID                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %%
df.columns=df.columns.str.capitalize()

# %%
df.nunique()
# Out:
# PRODUCT_ID             1351
# PRODUCT_NAME           1337
# CATEGORY                211
# DISCOUNTED_PRICE        550
# ACTUAL_PRICE            449
# DISCOUNT_PERCENTAGE      92
# RATING                   28
# RATING_COUNT           1143
# ABOUT_PRODUCT          1293
# USER_ID                1194
# USER_NAME              1194
# REVIEW_ID              1194
# REVIEW_TITLE           1194
# REVIEW_CONTENT         1212
# IMG_LINK               1412
# PRODUCT_LINK           1465
# dtype: int64

# %%
df.columns=df.columns.str.capitalize()

# %%
df.nunique()
# Out:
# Product_id             1351
# Product_name           1337
# Category                211
# Discounted_price        550
# Actual_price            449
# Discount_percentage      92
# Rating                   28
# Rating_count           1143
# About_product          1293
# User_id                1194
# User_name              1194
# Review_id              1194
# Review_title           1194
# Review_content         1212
# Img_link               1412
# Product_link           1465
# dtype: int64

# %%
df["Rating_count"]
# Out:
# 0       24,269
# 1       43,994
# 2        7,928
# 3       94,363
# 4       16,905
#          ...
# 1460     1,090
# 1461     4,118
# 1462       468
# 1463     8,031
# 1464     6,987
# Name: Rating_count, Length: 1465, dtype: object

# %%
df.isna().sum()
# Out:
# Product_id             0
# Product_name           0
# Category               0
# Discounted_price       0
# Actual_price           0
# Discount_percentage    0
# Rating                 0
# Rating_count           2
# About_product          0
# User_id                0
# User_name              0
# Review_id              0
# Review_title           0
# Review_content         0
# Img_link               0
# Product_link           0
# dtype: int64

# %%
df["Rating_count"]=df["Rating_count"].astype(str)
df["Rating_count"]=df["Rating_count"].str.replace(',','',regex=True)
df["Rating_count"]=pd.to_numeric(df["Rating_count"],errors="coerce")
m=round(df["Rating_count"].mean())
df["Rating_count"]=df["Rating_count"].fillna(m,inplace=True)
df["Rating_count"]=df["Rating_count"].astype('int64')

# %%
df.isna().sum()
# Out:
# Product_id                0
# Product_name              0
# Category                  0
# Discounted_price          0
# Actual_price              0
# Discount_percentage       0
# Rating                    0
# Rating_count              0
# About_product             0
# User_id                   0
# User_name                 0
# Review_id                 0
# Review_title              0
# Review_content            0
# Img_link                  0
# Product_link              0
# Review_count           1465
# dtype: int64

# %%
df.head()
# Out:
#    Product_id                                       Product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             Category Discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   Actual_price Discount_percentage Rating  Rating_count  \
# 0       ₹1,099                 64%    4.2           348
# ...

# %%
df["Rating_count"]
# Out:
# 0       348
# 1       348
# 2       348
# 3       348
# 4       348
#        ...
# 1460    348
# 1461    348
# 1462    468
# 1463    348
# 1464    348
# Name: Rating_count, Length: 1465, dtype: int64

# %%
df.drop(["Rating_count"],axis=1)
# Out:
#       Product_id                                       Product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                Category Discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %%
df.iloc[1:7]
# Out:
#    Product_id                                       Product_name  \
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# 5  B08Y1TFSP6  pTron Solero TB301 3A Type-C Data and Fast Cha...
# 6  B08WRWPM22  boAt Micro USB 55 Tangle-free, Sturdy Micro US...
#
#                                             Category Discounted_price  \
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
# 5  Computers&Accessories|Accessories&Peripherals|...             ₹149
# 6  Computers&Accessories|Accessories&Peripherals|...          ₹176.63
#
# ...

# %%
df.head(7)
# Out:
#    Product_id                                       Product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# 5  B08Y1TFSP6  pTron Solero TB301 3A Type-C Data and Fast Cha...
# 6  B08WRWPM22  boAt Micro USB 55 Tangle-free, Sturdy Micro US...
#
#                                             Category Discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
# ...

# %%
df.iloc[1]
# Out:
# Product_id                                                    B098NS6PVG
# Product_name           Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# Category               Computers&Accessories|Accessories&Peripherals|...
# Discounted_price                                                    ₹199
# Actual_price                                                        ₹349
# Discount_percentage                                                  43%
# Rating                                                               4.0
# Rating_count                                                        None
# About_product          Compatible with all Type C enabled devices, be...
# User_id                AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# User_name              ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# Review_id              RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# Review_title           A Good Braided Cable for Your Type C Device,Go...
# ...

# %%
df[0:4]
# Out:
#    Product_id                                       Product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
#
#                                             Category Discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
#
#   Actual_price Discount_percentage Rating Rating_count  \
# 0       ₹1,099                 64%    4.2         None
# 1         ₹349                 43%    4.0         None
# 2       ₹1,899                 90%    3.9         None
# 3         ₹699                 53%    4.2         None
#
# ...

# %%
rec=df[df["Discounted_price"]==199]
print(rec)
# Out:
#       Product_id                                       Product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                Category  Discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...               199
# ...

# %%
df.iloc[1:5,1:3]
# Out:
#                                         Product_name  \
# 1  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             Category
# 1  Computers&Accessories|Accessories&Peripherals|...
# 2  Computers&Accessories|Accessories&Peripherals|...
# 3  Computers&Accessories|Accessories&Peripherals|...
# 4  Computers&Accessories|Accessories&Peripherals|...

# %%
df.iloc[1,0]
# Out:
# 'B098NS6PVG'

# %%
df.iloc[:,2:5]
# Out:
#                                                Category  Discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...               199
# 1     Computers&Accessories|Accessories&Peripherals|...               199
# 2     Computers&Accessories|Accessories&Peripherals|...               199
# 3     Computers&Accessories|Accessories&Peripherals|...               199
# 4     Computers&Accessories|Accessories&Peripherals|...               199
# ...                                                 ...               ...
# 1460  Home&Kitchen|Kitchen&HomeAppliances|WaterPurif...               199
# 1461  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...               199
# 1462  Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...               199
# 1463  Home&Kitchen|Heating,Cooling&AirQuality|Fans|E...               199
# 1464  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...               199
#
#      Actual_price
# 0          ₹1,099
# 1            ₹349
# 2          ₹1,899
# ...

# %%
df.iloc[1:9,:]
# Out:
#    Product_id                                       Product_name  \
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# 5  B08Y1TFSP6  pTron Solero TB301 3A Type-C Data and Fast Cha...
# 6  B08WRWPM22  boAt Micro USB 55 Tangle-free, Sturdy Micro US...
# 7  B08DDRGWTJ             MI Usb Type-C Cable Smartphone (Black)
# 8  B008IFXQFU  TP-Link USB WiFi Adapter for PC(TL-WN725N), N1...
#
#                                             Category  Discounted_price  \
# 1  Computers&Accessories|Accessories&Peripherals|...               199
# 2  Computers&Accessories|Accessories&Peripherals|...               199
# 3  Computers&Accessories|Accessories&Peripherals|...               199
# 4  Computers&Accessories|Accessories&Peripherals|...               199
# ...

# %%
df.iloc[1,5]
# Out:
# '43%'

# %%
df.loc[1:2,"Product_id":"Rating"]
# Out:
#    Product_id                                       Product_name  \
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
#
#                                             Category  Discounted_price  \
# 1  Computers&Accessories|Accessories&Peripherals|...               199
# 2  Computers&Accessories|Accessories&Peripherals|...               199
#
#   Actual_price Discount_percentage Rating
# 1         ₹349                 43%    4.0
# 2       ₹1,899                 90%    3.9
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('Product_id').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
df.loc[:,"Rating"]
# Out:
# 0       4.2
# 1       4.0
# 2       3.9
# 3       4.2
# 4       4.2
#        ...
# 1460      4
# 1461    4.1
# 1462    3.6
# 1463      4
# 1464    4.3
# Name: Rating, Length: 1465, dtype: object

# %%
df.loc[1:8]
# Out:
#    Product_id                                       Product_name  \
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# 5  B08Y1TFSP6  pTron Solero TB301 3A Type-C Data and Fast Cha...
# 6  B08WRWPM22  boAt Micro USB 55 Tangle-free, Sturdy Micro US...
# 7  B08DDRGWTJ             MI Usb Type-C Cable Smartphone (Black)
# 8  B008IFXQFU  TP-Link USB WiFi Adapter for PC(TL-WN725N), N1...
#
#                                             Category  Discounted_price  \
# 1  Computers&Accessories|Accessories&Peripherals|...               199
# 2  Computers&Accessories|Accessories&Peripherals|...               199
# 3  Computers&Accessories|Accessories&Peripherals|...               199
# 4  Computers&Accessories|Accessories&Peripherals|...               199
# ...

# %%
df.drop(["Review_count"],axis=1)
# Out:
#       Product_id                                       Product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                Category  Discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...               199
# ...

# %%
# Filtering the data
filter1=df["Actual_price"] > 1099
filter2=df["Actual_price"] < 3000
print(df[filter1&filter2])

# %%
df["Actual_price"]=df["Actual_price"].astype(str)
df["Actual_price"]=df["Actual_price"].str.replace(',','')
df["Actual_price"]=pd.to_numeric(df['Actual_price'],errors="coerce")
filter1=df['Actual_price'] > 1099
filter2=df['Actual_price'] > 3000
print(df[filter1 & filter2])
# Out:
# Empty DataFrame
# Columns: [Product_id, Product_name, Category, Discounted_price, Actual_price, Discount_percentage, Rating, Rating_count, About_product, User_id, User_name, Review_id, Review_title, Review_content, Img_link, Product_link, Review_count, actual_price]
# Index: []

# %%
df["Actual_price"].dtypes
# Out:
# dtype('O')

# %%
df.dtypes
# Out:
# Product_id              object
# Product_name            object
# Category                object
# Discounted_price         int64
# Actual_price            object
# Discount_percentage     object
# Rating                  object
# Rating_count            object
# About_product           object
# User_id                 object
# User_name               object
# Review_id               object
# Review_title            object
# Review_content          object
# Img_link                object
# Product_link            object
# Review_count            object
# actual_price           float64
# dtype: object

# %%
df.head(4)
# Out:
#    Product_id                                       Product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
#
#                                             Category  Discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...               199
# 1  Computers&Accessories|Accessories&Peripherals|...               199
# 2  Computers&Accessories|Accessories&Peripherals|...               199
# 3  Computers&Accessories|Accessories&Peripherals|...               199
#
#    Actual_price Discount_percentage Rating Rating_count  \
# 0           NaN                 64%    4.2         None
# 1           NaN                 43%    4.0         None
# 2           NaN                 90%    3.9         None
# ...

# %%
df.drop(["actual_price"],axis=1)
# Out:
#       Product_id                                       Product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                Category  Discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...               199
# ...

# %%
df["Rating"]=pd.to_numeric(df["Rating"],errors="coerce")
fil1=df["Rating"] >3.0
fil2=df["Rating"] <4.0
print(df[fil1 & fil2])
# Out:
#       Product_id                                       Product_name  \
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 5     B08Y1TFSP6  pTron Solero TB301 3A Type-C Data and Fast Cha...
# 21    B085194JFL  tizum HDMI to VGA Adapter Cable 1080P for Proj...
# 34    B0B4HJNPV4  pTron Solero T351 3.5Amps Fast Charging Type-C...
# 35    B08Y1SJVV5  pTron Solero MB301 3A Micro USB Data & Chargin...
# ...          ...                                                ...
# 1454  B08ZXZ362Z  akiara - Makes life easy Mini Sewing Machine f...
# 1456  B0B9JZW1SQ  4 in 1 Handheld Electric Vegetable Cutter Set,...
# 1458  B07J9KXQCC  Libra Room Heater for Home, Room Heaters Home ...
# 1459  B0B3JSWG81  NGI Store 2 Pieces Pet Hair Removers for Your ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
#
#                                                Category  Discounted_price  \
# 2     Computers&Accessories|Accessories&Peripherals|...               199
# ...

# %%
df2=df["Rating"].unique()
print(df2)
# Out:
# [4.2 4.  3.9 4.1 4.3 4.4 4.5 3.7 3.3 3.6 3.4 3.8 3.5 4.6 3.2 5.  4.7 3.
#  2.8 3.1 4.8 2.3 nan 2.  2.6 2.9]

# %%
#sorting a dataframe
df2=df.sort_values(by="Rating",ascending=False)
print(df2)
# Out:
#       Product_id                                       Product_name  \
# 174   B0BP7XLX48  Syncwire LTG to USB Cable for Fast Charging Co...
# 324   B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
# 775   B09ZHCJDP1  Amazon Basics Wireless Mouse | 2.4 GHz Connect...
# 1299  B0B53DS4TF  Instant Pot Air Fryer, Vortex 2QT, Touch Contr...
# 1201  B0BQ3K23Y1  Oratech Coffee Frother electric, milk frother ...
# ...          ...                                                ...
# 545   B0BBVKRP7B  SHREENOVA ID116 Plus Bluetooth Fitness Smart W...
# 1356  B0B7L86YCB  Green Tales Heat Seal Mini Food Sealer-Impulse...
# 1243  B0BFBNXS94  Personal Size Blender, Portable Blender, Batte...
# 1309  B0BPJBTB3F  Khaitan ORFin Fan heater for Home and kitchen-...
# 1279  B08L12N5H1  Eureka Forbes car Vac 100 Watts Powerful Sucti...
#
#                                                Category  Discounted_price  \
# 174   Computers&Accessories|Accessories&Peripherals|...               199
# ...

# %%
# in anotherway of sorting
df2=df["Rating"].sort_values()
print(df2)
# Out:
# 1309    2.0
# 1243    2.3
# 1356    2.6
# 545     2.8
# 1286    2.8
#        ...
# 1299    4.8
# 174     5.0
# 775     5.0
# 324     5.0
# 1279    NaN
# Name: Rating, Length: 1465, dtype: float64

# %%
#Groupby
cols=["Rating","Product_name"]
df2=df.groupby(cols).size()
print(df2)
# Out:
# Rating  Product_name
# 2.0     Khaitan ORFin Fan heater for Home and kitchen-K0 2215                                                                                                                                                                                                                           1
# 2.3     Personal Size Blender, Portable Blender, Battery Powered USB Blender, with Four Blades, Mini Blender Travel Bottle for Juice, Shakes, and Smoothies (Pink)                                                                                                                      1
# 2.6     Green Tales Heat Seal Mini Food Sealer-Impulse Machine for Sealing Plastic Bags Packaging                                                                                                                                                                                       1
# ...

# %%
df.head()
# Out:
#    Product_id                                       Product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             Category  Discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...               199
# 1  Computers&Accessories|Accessories&Peripherals|...               199
# 2  Computers&Accessories|Accessories&Peripherals|...               199
# 3  Computers&Accessories|Accessories&Peripherals|...               199
# 4  Computers&Accessories|Accessories&Peripherals|...               199
#
#    Actual_price Discount_percentage  Rating Rating_count  \
# 0           NaN                 64%     4.2         None
# ...

# %%
cols=["Product_name","Rating"]
df2=df.groupby(cols,as_index=False)["Category"]
print(df2.sum())
# Out:
#                                            Product_name  Rating  \
# 0     !!1000 Watt/2000-Watt Room Heater!! Fan Heater...     4.5
# 1     !!HANEUL!!1000 Watt/2000-Watt Room Heater!! Fa...     3.4
# 2     10WeRun Id-116 Bluetooth Smartwatch Wireless F...     4.1
# 3     10k 8k 4k HDMI Cable, Certified 48Gbps 1ms Ult...     4.6
# 4     3M Post-it Sticky Note Cube, 200 Sheets (4 Col...     4.4
# ...                                                 ...     ...
# 1332  realme Buds Wireless in Ear Bluetooth Earphone...     4.1
# 1333  realme narzo 50 (Speed Blue, 4GB RAM+64GB Stor...     4.2
# 1334  realme narzo 50i (Mint Green, 2GB RAM+32GB Sto...     4.0
# 1335  rts [2 Pack] Mini USB C Type C Adapter Plug, T...     4.3
# 1336  tizum HDMI to VGA Adapter Cable 1080P for Proj...     3.7
#
#                                                Category
# 0     Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...
# 1     Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...
# ...

# %%
#sorting
df2=df.sort_values(by="Category",ascending=True)
print(df2)
# Out:
#       Product_id                                       Product_name  \
# 1157  B0912WJ87V  Reffair AX30 [MAX] Portable Air Purifier for C...
# 695   B097C564GC  rts [2 Pack] Mini USB C Type C Adapter Plug, T...
# 742   B094DQWV9B  Kanget [2 Pack] Type C Female to USB A Male Ch...
# 906   B009LJ2BXA  Hp Wired On Ear Headphones With Mic With 3.5 M...
# 748   B08SCCG9D4  JBL Commercial CSLM20B Auxiliary Omnidirection...
# ...          ...                                                ...
# 858   B00LOD70SC  Pilot V7 Liquid Ink Roller Ball Pen (2 Blue + ...
# 850   B07SBGFDX9     Pentonic Multicolor Ball Point Pen, Pack of 10
# 919   B00LZPQVMK  Parker Vector Standard Chrome Trim Ball Pen (I...
# 955   B0746N6WML  Parker Vector Camouflage Gift Set - Roller Bal...
# 924   B00DJ5N9VK  Faber-Castell Connector Pen Set - Pack of 25 (...
#
#                                                Category  Discounted_price  \
# 1157  Car&Motorbike|CarAccessories|InteriorAccessori...               199
# ...

# %%
df2.head(126)
# Out:
#       Product_id                                       Product_name  \
# 1157  B0912WJ87V  Reffair AX30 [MAX] Portable Air Purifier for C...
# 695   B097C564GC  rts [2 Pack] Mini USB C Type C Adapter Plug, T...
# 742   B094DQWV9B  Kanget [2 Pack] Type C Female to USB A Male Ch...
# 906   B009LJ2BXA  Hp Wired On Ear Headphones With Mic With 3.5 M...
# 748   B08SCCG9D4  JBL Commercial CSLM20B Auxiliary Omnidirection...
# ...          ...                                                ...
# 266   B0B61HYR92  Lapster usb 2.0 mantra cable, mantra mfs 100 d...
# 261   B07F1P8KNV  Wayona Nylon Braided Usb Type C 3Ft 1M 3A Fast...
# 259   B07DWFX9YS  Amazon Basics USB A to Lightning PVC Molded Ny...
# 258   B07CRL2GY6  boAt Rugged V3 Braided Micro USB Cable (Pearl ...
# 257   B08CT62BM1  Wayona USB Type C Fast Charging Cable Charger ...
#
#                                                Category  Discounted_price  \
# 1157  Car&Motorbike|CarAccessories|InteriorAccessori...               199
# ...

# %%
# To delete specific columns
df.drop(["Actual_price","actual_price"],axis=1)
# Out:
#       Product_id                                       Product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                Category  Discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...               199
# ...

# %%
# to delete specific rows
rows=[1464,1463]
df.drop(rows,axis=0)
# Out:
#       Product_id                                       Product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1458  B07J9KXQCC  Libra Room Heater for Home, Room Heaters Home ...
# 1459  B0B3JSWG81  NGI Store 2 Pieces Pet Hair Removers for Your ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
#
#                                                Category  Discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...               199
# ...

# %%
# to add a new column
df["Address"]="London,England"

# %%
df.head()
# Out:
#    Product_id                                       Product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             Category  Discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...               199
# 1  Computers&Accessories|Accessories&Peripherals|...               199
# 2  Computers&Accessories|Accessories&Peripherals|...               199
# 3  Computers&Accessories|Accessories&Peripherals|...               199
# 4  Computers&Accessories|Accessories&Peripherals|...               199
#
#    Actual_price Discount_percentage  Rating Rating_count  \
# 0           NaN                 64%     4.2         None
# ...

# %%
# To insert a specific column at a position
a="Christmas Fest"
df.insert(3,"Offer",a)

# %%
df[1:4]
# Out:
#    Product_id                                       Product_name  \
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
#
#                                             Category           Offer  \
# 1  Computers&Accessories|Accessories&Peripherals|...  Christmas Fest
# 2  Computers&Accessories|Accessories&Peripherals|...  Christmas Fest
# 3  Computers&Accessories|Accessories&Peripherals|...  Christmas Fest
#
#    Discounted_price  Actual_price Discount_percentage  Rating Rating_count  \
# 1               199           NaN                 43%     4.0         None
# 2               199           NaN                 90%     3.9         None
# 3               199           NaN                 53%     4.2         None
#
#                                        About_product  \
# 1  Compatible with all Type C enabled devices, be...
# ...

# %%
df.to_csv("Updated_amazon.csv")
